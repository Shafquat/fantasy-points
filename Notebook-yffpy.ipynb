# %%
import yffpy
from yffpy.query import YahooFantasyFootballQuery
import json
import openpyxl
from datetime import date

# %%
league_id = '43832' # put your real league id here
game_id = "396"
game_code = "nhl"
season = "2019"
auth_dir = 'X:/yffpy-batch/'

# %%
yahoo_query = YahooFantasyFootballQuery(auth_dir, league_id, game_id=game_id, game_code=game_code, offline=False)

# %%
#yahoo_query.get_team_draft_results(1)
# Out:
# [2019-10-03 14:11:05,763 DEBUG] [yffpy.query.query.query] Response (JSON): {'fantasy_content': {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/game/396/metadata', 'game': [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}], 'time': '8.8388919830322ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}}
# [2019-10-03 14:11:05,764 DEBUG] [yffpy.query.query.query] Data fetched with query URL: https://fantasysports.yahooapis.com/fantasy/v2/game/396/metadata?format=json
# [2019-10-03 14:11:05,764 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: "fantasy_content"): {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/game/396/metadata', 'game': [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}], 'time': '8.8388919830322ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}
# [2019-10-03 14:11:05,765 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: ['game']): [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}]
# [2019-10-03 14:11:05,768 DEBUG] [yffpy.query.query.query] Unpacked and parsed JSON (Yahoo fantasy data wth parent type: <class 'yffpy.models.Game'>):
# {'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}
# [2019-10-03 14:11:05,840 DEBUG] [yffpy.query.query.query] Response (JSON): {'fantasy_content': {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/team/396.l.43832.t.1/draftresults', 'team': [[{'team_key': '396.l.43832.t.1'}, {'team_id': '1'}, {'name': "Oren's Team"}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/1'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://ct.yimg.com/cy/1689/24999113210_66a2698cec_192sq.jpg?ct=fantasy'}}]}, [], {'waiver_priority': 15}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 5}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '1', 'nickname': 'Oren', 'guid': 'IL3XCIOS3EMGHZ6LKMPFSSO2XE', 'is_commissioner': '1', 'email': 'oren.winer@gmail.com', 'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg'}}]}], {'draft_results': {'0': {'draft_result': {'pick': 5, 'round': 1, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5980'}}, '1': {'draft_result': {'pick': 34, 'round': 2, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3764'}}, '2': {'draft_result': {'pick': 43, 'round': 3, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3614'}}, '3': {'draft_result': {'pick': 72, 'round': 4, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5364'}}, '4': {'draft_result': {'pick': 81, 'round': 5, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3981'}}, '5': {'draft_result': {'pick': 110, 'round': 6, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.2645'}}, '6': {'draft_result': {'pick': 119, 'round': 7, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5279'}}, '7': {'draft_result': {'pick': 148, 'round': 8, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4792'}}, '8': {'draft_result': {'pick': 157, 'round': 9, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4251'}}, '9': {'draft_result': {'pick': 186, 'round': 10, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.6060'}}, 'count': 10}}], 'time': '19.519805908203ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}}
# [2019-10-03 14:11:05,841 DEBUG] [yffpy.query.query.query] Data fetched with query URL: https://fantasysports.yahooapis.com/fantasy/v2/team/396.l.43832.t.1/draftresults?format=json
# [2019-10-03 14:11:05,841 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: "fantasy_content"): {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/team/396.l.43832.t.1/draftresults', 'team': [[{'team_key': '396.l.43832.t.1'}, {'team_id': '1'}, {'name': "Oren's Team"}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/1'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://ct.yimg.com/cy/1689/24999113210_66a2698cec_192sq.jpg?ct=fantasy'}}]}, [], {'waiver_priority': 15}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 5}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '1', 'nickname': 'Oren', 'guid': 'IL3XCIOS3EMGHZ6LKMPFSSO2XE', 'is_commissioner': '1', 'email': 'oren.winer@gmail.com', 'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg'}}]}], {'draft_results': {'0': {'draft_result': {'pick': 5, 'round': 1, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5980'}}, '1': {'draft_result': {'pick': 34, 'round': 2, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3764'}}, '2': {'draft_result': {'pick': 43, 'round': 3, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3614'}}, '3': {'draft_result': {'pick': 72, 'round': 4, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5364'}}, '4': {'draft_result': {'pick': 81, 'round': 5, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3981'}}, '5': {'draft_result': {'pick': 110, 'round': 6, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.2645'}}, '6': {'draft_result': {'pick': 119, 'round': 7, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5279'}}, '7': {'draft_result': {'pick': 148, 'round': 8, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4792'}}, '8': {'draft_result': {'pick': 157, 'round': 9, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4251'}}, '9': {'draft_result': {'pick': 186, 'round': 10, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.6060'}}, 'count': 10}}], 'time': '19.519805908203ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}
# [2019-10-03 14:11:05,842 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: ['team', 'draft_results']): {'0': {'draft_result': {'pick': 5, 'round': 1, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5980'}}, '1': {'draft_result': {'pick': 34, 'round': 2, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3764'}}, '2': {'draft_result': {'pick': 43, 'round': 3, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3614'}}, '3': {'draft_result': {'pick': 72, 'round': 4, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5364'}}, '4': {'draft_result': {'pick': 81, 'round': 5, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.3981'}}, '5': {'draft_result': {'pick': 110, 'round': 6, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.2645'}}, '6': {'draft_result': {'pick': 119, 'round': 7, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.5279'}}, '7': {'draft_result': {'pick': 148, 'round': 8, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4792'}}, '8': {'draft_result': {'pick': 157, 'round': 9, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.4251'}}, '9': {'draft_result': {'pick': 186, 'round': 10, 'team_key': '396.l.43832.t.1', 'player_key': '396.p.6060'}}, 'count': 10}
# [2019-10-03 14:11:05,867 DEBUG] [yffpy.query.query.query] Unpacked and parsed JSON (Yahoo fantasy data wth parent type: None):
# [{'draft_result': {
#   "pick": 5,
#   "round": 1,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.5980"
# }}, {'draft_result': {
#   "pick": 34,
#   "round": 2,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.3764"
# }}, {'draft_result': {
#   "pick": 43,
#   "round": 3,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.3614"
# }}, {'draft_result': {
#   "pick": 72,
#   "round": 4,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.5364"
# }}, {'draft_result': {
#   "pick": 81,
#   "round": 5,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.3981"
# }}, {'draft_result': {
#   "pick": 110,
#   "round": 6,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.2645"
# }}, {'draft_result': {
#   "pick": 119,
#   "round": 7,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.5279"
# }}, {'draft_result': {
#   "pick": 148,
#   "round": 8,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.4792"
# }}, {'draft_result': {
#   "pick": 157,
#   "round": 9,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.4251"
# }}, {'draft_result': {
#   "pick": 186,
#   "round": 10,
#   "team_key": "396.l.43832.t.1",
#   "player_key": "396.p.6060"
# }}]
# [{'draft_result': {
#     "pick": 5,
#     "round": 1,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.5980"
#   }}, {'draft_result': {
#     "pick": 34,
#     "round": 2,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.3764"
#   }}, {'draft_result': {
#     "pick": 43,
#     "round": 3,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.3614"
#   }}, {'draft_result': {
#     "pick": 72,
#     "round": 4,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.5364"
#   }}, {'draft_result': {
#     "pick": 81,
#     "round": 5,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.3981"
#   }}, {'draft_result': {
#     "pick": 110,
#     "round": 6,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.2645"
#   }}, {'draft_result': {
#     "pick": 119,
#     "round": 7,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.5279"
#   }}, {'draft_result': {
#     "pick": 148,
#     "round": 8,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.4792"
#   }}, {'draft_result': {
#     "pick": 157,
#     "round": 9,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.4251"
#   }}, {'draft_result': {
#     "pick": 186,
#     "round": 10,
#     "team_key": "396.l.43832.t.1",
#     "player_key": "396.p.6060"
#   }}]

# %%
#yahoo_query.get_game_stat_categories_by_game_id(game_id)

# %%
standings_data = yahoo_query.get_league_standings()
# Out:
# [2019-10-03 09:11:54,427 DEBUG] [yffpy.query.query.query] Response (JSON): {'fantasy_content': {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/game/396/metadata', 'game': [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}], 'time': '27.086019515991ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}}
# [2019-10-03 09:11:57,488 DEBUG] [yffpy.query.query.query] Data fetched with query URL: https://fantasysports.yahooapis.com/fantasy/v2/game/396/metadata?format=json
# [2019-10-03 09:11:57,488 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: "fantasy_content"): {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/game/396/metadata', 'game': [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}], 'time': '27.086019515991ms', 'copyright': 'Data provided by Yahoo! and STATS, LLC', 'refresh_rate': '60'}
# [2019-10-03 09:11:57,488 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: ['game']): [{'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}]
# [2019-10-03 09:11:57,488 DEBUG] [yffpy.query.query.query] Unpacked and parsed JSON (Yahoo fantasy data wth parent type: <class 'yffpy.models.Game'>):
# {'game_key': '396', 'game_id': '396', 'name': 'Hockey', 'code': 'nhl', 'type': 'full', 'url': 'https://hockey.fantasysports.yahoo.com/hockey', 'season': '2019', 'is_registration_over': 0, 'is_game_over': 0, 'is_offseason': 0, 'is_live_draft_lobby_active': 1}
# [2019-10-03 09:11:57,658 DEBUG] [yffpy.query.query.query] Response (JSON): {'fantasy_content': {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/league/396.l.43832/standings', 'league': [{'league_key': '396.l.43832', 'league_id': '43832', 'name': '14th Floor Hockey Pool', 'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832', 'logo_url': 'https://ct.yimg.com/cy/1881/44016851925_18dae2_192sq.jpg?ct=fantasy', 'draft_status': 'postdraft', 'num_teams': 19, 'edit_key': '2019-10-04', 'weekly_deadline': '', 'league_update_timestamp': '1570084358', 'scoring_type': 'point', 'league_type': 'private', 'renew': '386_76028', 'renewed': '', 'iris_group_chat_id': 'DRAUMBH3N5ELDKFW3R5DU5I3OI', 'allow_add_to_dl_extra_pos': 1, 'is_pro_league': '0', 'is_cash_league': '0', 'start_date': '2019-10-02', 'end_date': '2020-04-04', 'game_code': 'nhl', 'season': '2019'}, {'standings': [{'teams': {'0': {'team': [[{'team_key': '396.l.43832.t.17'}, {'team_id': '17'}, {'name': "Jarrod's Team"}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/17'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_10_j.png'}}]}, [], {'waiver_priority': 6}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 14}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '17', 'nickname': 'Jarrod', 'guid': 'RJ4HIRHI5ZZ47QXMQZB5NWB4AY', 'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '4'}}, {'stat': {'stat_id': '4', 'value': '3'}}, {'stat': {'stat_id': '14', 'value': '7'}}, {'stat': {'stat_id': '19', 'value': '0'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '0'}}, {'stat': {'stat_id': '25', 'value': '0'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season': '2019', 'total': '14.25', 'stats': [{'stat': {'stat_id': '1', 'value': '3.00'}}, {'stat': {'stat_id': '2', 'value': '8.00'}}, {'stat': {'stat_id': '4', 'value': '1.50'}}, {'stat': {'stat_id': '14', 'value': '1.75'}}, {'stat': {'stat_id': '19', 'value': '0.00'}}, {'stat': {'stat_id': '20', 'value': '0.00'}}, {'stat': {'stat_id': '22', 'value': '0.00'}}, {'stat': {'stat_id': '25', 'value': '0.00'}}, {'stat': {'stat_id': '27', 'value': '0.00'}}]}}, {'team_standings': {'rank': '1', 'points_for': '14.25', 'points_change': 0, 'points_back': '0.00'}}]}, '1': {'team': [[{'team_key': '396.l.43832.t.14'}, {'team_id': '14'}, {'name': 'The Mighty Pigs'}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/14'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://ct.yimg.com/cy/1814/56476657725_8e0322_192sq.jpg?ct=fantasy'}}]}, [], {'waiver_priority': 17}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 3}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '14', 'nickname': 'David', 'guid': 'QHYQ4K3QJIQAFIN3PNNLLG6W34', 'email': 'david.r.w.babin@gmail.com', 'image_url': 'https://s.yimg.com/ag/images/4734/37610911593_62bc59_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '2'}}, {'stat': {'stat_id': '4', 'value': '-2'}}, {'stat': {'stat_id': '14', 'value': '12'}}, {'stat': {'stat_id': '19', 'value': '1'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '2'}}, {'stat': {'stat_id': '25', 'value': '20'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season': '2019', 'total': '13.00', 's ...
# [2019-10-03 09:11:57,658 DEBUG] [yffpy.query.query.query] Data fetched with query URL: https://fantasysports.yahooapis.com/fantasy/v2/league/396.l.43832/standings?format=json
# [2019-10-03 09:11:57,673 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: "fantasy_content"): {'xml:lang': 'en-US', 'yahoo:uri': '/fantasy/v2/league/396.l.43832/standings', 'league': [{'league_key': '396.l.43832', 'league_id': '43832', 'name': '14th Floor Hockey Pool', 'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832', 'logo_url': 'https://ct.yimg.com/cy/1881/44016851925_18dae2_192sq.jpg?ct=fantasy', 'draft_status': 'postdraft', 'num_teams': 19, 'edit_key': '2019-10-04', 'weekly_deadline': '', 'league_update_timestamp': '1570084358', 'scoring_type': 'point', 'league_type': 'private', 'renew': '386_76028', 'renewed': '', 'iris_group_chat_id': 'DRAUMBH3N5ELDKFW3R5DU5I3OI', 'allow_add_to_dl_extra_pos': 1, 'is_pro_league': '0', 'is_cash_league': '0', 'start_date': '2019-10-02', 'end_date': '2020-04-04', 'game_code': 'nhl', 'season': '2019'}, {'standings': [{'teams': {'0': {'team': [[{'team_key': '396.l.43832.t.17'}, {'team_id': '17'}, {'name': "Jarrod's Team"}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/17'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_10_j.png'}}]}, [], {'waiver_priority': 6}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 14}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '17', 'nickname': 'Jarrod', 'guid': 'RJ4HIRHI5ZZ47QXMQZB5NWB4AY', 'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '4'}}, {'stat': {'stat_id': '4', 'value': '3'}}, {'stat': {'stat_id': '14', 'value': '7'}}, {'stat': {'stat_id': '19', 'value': '0'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '0'}}, {'stat': {'stat_id': '25', 'value': '0'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season': '2019', 'total': '14.25', 'stats': [{'stat': {'stat_id': '1', 'value': '3.00'}}, {'stat': {'stat_id': '2', 'value': '8.00'}}, {'stat': {'stat_id': '4', 'value': '1.50'}}, {'stat': {'stat_id': '14', 'value': '1.75'}}, {'stat': {'stat_id': '19', 'value': '0.00'}}, {'stat': {'stat_id': '20', 'value': '0.00'}}, {'stat': {'stat_id': '22', 'value': '0.00'}}, {'stat': {'stat_id': '25', 'value': '0.00'}}, {'stat': {'stat_id': '27', 'value': '0.00'}}]}}, {'team_standings': {'rank': '1', 'points_for': '14.25', 'points_change': 0, 'points_back': '0.00'}}]}, '1': {'team': [[{'team_key': '396.l.43832.t.14'}, {'team_id': '14'}, {'name': 'The Mighty Pigs'}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/14'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://ct.yimg.com/cy/1814/56476657725_8e0322_192sq.jpg?ct=fantasy'}}]}, [], {'waiver_priority': 17}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 3}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '14', 'nickname': 'David', 'guid': 'QHYQ4K3QJIQAFIN3PNNLLG6W34', 'email': 'david.r.w.babin@gmail.com', 'image_url': 'https://s.yimg.com/ag/images/4734/37610911593_62bc59_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '2'}}, {'stat': {'stat_id': '4', 'value': '-2'}}, {'stat': {'stat_id': '14', 'value': '12'}}, {'stat': {'stat_id': '19', 'value': '1'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '2'}}, {'stat': {'stat_id': '25', 'value': '20'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season':  ...
# [2019-10-03 09:11:57,673 DEBUG] [yffpy.query.query.query] Response (Yahoo fantasy data extracted from: ['league', 'standings']): [{'teams': {'0': {'team': [[{'team_key': '396.l.43832.t.17'}, {'team_id': '17'}, {'name': "Jarrod's Team"}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/17'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_10_j.png'}}]}, [], {'waiver_priority': 6}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 14}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '17', 'nickname': 'Jarrod', 'guid': 'RJ4HIRHI5ZZ47QXMQZB5NWB4AY', 'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '4'}}, {'stat': {'stat_id': '4', 'value': '3'}}, {'stat': {'stat_id': '14', 'value': '7'}}, {'stat': {'stat_id': '19', 'value': '0'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '0'}}, {'stat': {'stat_id': '25', 'value': '0'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season': '2019', 'total': '14.25', 'stats': [{'stat': {'stat_id': '1', 'value': '3.00'}}, {'stat': {'stat_id': '2', 'value': '8.00'}}, {'stat': {'stat_id': '4', 'value': '1.50'}}, {'stat': {'stat_id': '14', 'value': '1.75'}}, {'stat': {'stat_id': '19', 'value': '0.00'}}, {'stat': {'stat_id': '20', 'value': '0.00'}}, {'stat': {'stat_id': '22', 'value': '0.00'}}, {'stat': {'stat_id': '25', 'value': '0.00'}}, {'stat': {'stat_id': '27', 'value': '0.00'}}]}}, {'team_standings': {'rank': '1', 'points_for': '14.25', 'points_change': 0, 'points_back': '0.00'}}]}, '1': {'team': [[{'team_key': '396.l.43832.t.14'}, {'team_id': '14'}, {'name': 'The Mighty Pigs'}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/14'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://ct.yimg.com/cy/1814/56476657725_8e0322_192sq.jpg?ct=fantasy'}}]}, [], {'waiver_priority': 17}, [], {'number_of_moves': 0}, {'number_of_trades': 0}, {'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'}}, [], {'league_scoring_type': 'point'}, [], {'draft_position': 3}, {'has_draft_grade': 0}, [], [], {'managers': [{'manager': {'manager_id': '14', 'nickname': 'David', 'guid': 'QHYQ4K3QJIQAFIN3PNNLLG6W34', 'email': 'david.r.w.babin@gmail.com', 'image_url': 'https://s.yimg.com/ag/images/4734/37610911593_62bc59_64sq.jpg'}}]}], {'team_stats': {'coverage_type': 'season', 'season': '2019', 'stats': [{'stat': {'stat_id': '1', 'value': '1'}}, {'stat': {'stat_id': '2', 'value': '2'}}, {'stat': {'stat_id': '4', 'value': '-2'}}, {'stat': {'stat_id': '14', 'value': '12'}}, {'stat': {'stat_id': '19', 'value': '1'}}, {'stat': {'stat_id': '20', 'value': '0'}}, {'stat': {'stat_id': '22', 'value': '2'}}, {'stat': {'stat_id': '25', 'value': '20'}}, {'stat': {'stat_id': '27', 'value': '0'}}]}, 'team_points': {'coverage_type': 'season', 'season': '2019', 'total': '13.00', 'stats': [{'stat': {'stat_id': '1', 'value': '3.00'}}, {'stat': {'stat_id': '2', 'value': '4.00'}}, {'stat': {'stat_id': '4', 'value': '-1.00'}}, {'stat': {'stat_id': '14', 'value': '3.00'}}, {'stat': {'stat_id': '19', 'value': '2.00'}}, {'stat': {'stat_id': '20', 'value': '0.00'}}, {'stat': {'stat_id': '22', 'value': '-2.00'}}, {'stat': {'stat_id': '25', 'value': '4.00'}}, {'stat': {'stat_id': '27', 'value': '0.00'}}]}}, {'team_standings': {'rank': '2', 'points_for': '13.00', 'points_change': 0, 'points_back': '1.25'}}]}, '2': {'team': [[{'team_key': '396.l.43832.t.6'}, {'team_id': '6'}, {'name': 'Klin Krush'}, [], {'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/6'}, {'team_logos': [{'team_logo': {'size': 'large', 'url': 'htt ...
# [2019-10-03 09:11:58,408 DEBUG] [yffpy.query.query.query] Unpacked and parsed JSON (Yahoo fantasy data wth parent type: <class 'yffpy.models.Standings'>):
# {'teams': [{'team': {
#   "draft_position": 14,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "guid": "RJ4HIRHI5ZZ47QXMQZB5NWB4AY",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "17",
#       "nickname": "Jarrod"
#     }
#   },
#   "name": "Jarrod's Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "17",
#   "team_key": "396.l.43832.t.17",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_10_j.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "14.25"
#   },
#   "team_standings": {
#     "points_for": 14.25,
#     "rank": "1"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/17",
#   "waiver_priority": 6
# }}, {'team': {
#   "draft_position": 3,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "david.r.w.babin@gmail.com",
#       "guid": "QHYQ4K3QJIQAFIN3PNNLLG6W34",
#       "image_url": "https://s.yimg.com/ag/images/4734/37610911593_62bc59_64sq.jpg",
#       "manager_id": "14",
#       "nickname": "David"
#     }
#   },
#   "name": "The Mighty Pigs",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "14",
#   "team_key": "396.l.43832.t.14",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1814/56476657725_8e0322_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "13.00"
#   },
#   "team_standings": {
#     "points_for": 13.0,
#     "rank": "2"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/14",
#   "waiver_priority": 17
# }}, {'team': {
#   "draft_position": 4,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "franklin27@rogers.com",
#       "guid": "RTEILUK2MOBO5QGIMA76QPWDVA",
#       "image_url": "https://s.yimg.com/ag/images/4543/37864449670_ab6299_64sq.jpg",
#       "manager_id": "6",
#       "nickname": "-- hidden --"
#     }
#   },
#   "name": "Klin Krush",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "6",
#   "team_key": "396.l.43832.t.6",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_4.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "12.30"
#   },
#   "team_standings": {
#     "points_for": 12.3,
#     "rank": "3"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/6",
#   "waiver_priority": 16
# }}, {'team': {
#   "draft_position": 1,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "mrhockeypool@yahoo.com",
#       "guid": "PRCXYO3L6I7LVENMOBV5BZS272",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "9",
#       "nickname": "Stacey"
#     }
#   },
#   "name": "Stacey's Superb Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "9",
#   "team_key": "396.l.43832.t.9",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "12.00"
#   },
#   "team_standings": {
#     "points_for": 12.0,
#     "rank": "4"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/9",
#   "waiver_priority": 19
# }}, {'team': {
#   "draft_position": 7,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "spaglia@osc.gov.on.ca",
#       "guid": "G54BIFJKC3RV2A2UQFQYPCCSGQ",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "18",
#       "nickname": "Stephen"
#     }
#   },
#   "name": "Benchwarmers",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "18",
#   "team_key": "396.l.43832.t.18",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_8_b.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "11.25"
#   },
#   "team_standings": {
#     "points_for": 11.25,
#     "rank": "5"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/18",
#   "waiver_priority": 13
# }}, {'team': {
#   "draft_position": 11,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "miaolong188@yahoo.com",
#       "guid": "54QN76SM6FIBZNCDJE3CJV4OMM",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "13",
#       "nickname": "Yani"
#     }
#   },
#   "name": "Yani's Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "13",
#   "team_key": "396.l.43832.t.13",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/5046/29952449886_8df2d26330_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "11.20"
#   },
#   "team_standings": {
#     "points_for": 11.2,
#     "rank": "6"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/13",
#   "waiver_priority": 9
# }}, {'team': {
#   "draft_position": 12,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "michaelbalter@rogers.com",
#       "guid": "JAAVAZCMHCSOBC326TUKMLRONQ",
#       "image_url": "https://s.yimg.com/ag/images/4460/37419124544_bb126c_64sq.jpg",
#       "manager_id": "19",
#       "nickname": "Fig"
#     }
#   },
#   "name": "Air Duct Cleaners",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "19",
#   "team_key": "396.l.43832.t.19",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_5_m.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "9.20"
#   },
#   "team_standings": {
#     "points_for": 9.2,
#     "rank": "7"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/19",
#   "waiver_priority": 8
# }}, {'team': {
#   "draft_position": 15,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "jonkatz85@yahoo.ca",
#       "guid": "4LTCKD42U7P7OJ45FZ53W4U2IY",
#       "image_url": "https://s.yimg.com/ag/images/4573/38099892752_6f450d_64sq.jpg",
#       "manager_id": "15",
#       "nickname": "Jon"
#     }
#   },
#   "name": "Jon's Team",
#   "number_of_moves": "1",
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "15",
#   "team_key": "396.l.43832.t.15",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_5_j.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "8.25"
#   },
#   "team_standings": {
#     "points_for": 8.25,
#     "rank": "8"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/15",
#   "waiver_priority": 5
# }}, {'team': {
#   "draft_position": 8,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "smolson12@yahoo.com",
#       "guid": "MDDMPDULM5IFFUGJ3QAKIEZ5GQ",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "5",
#       "nickname": "shaun"
#     }
#   },
#   "name": "Dropping The Gloves",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "5",
#   "team_key": "396.l.43832.t.5",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "7.50"
#   },
#   "team_standings": {
#     "points_for": 7.5,
#     "rank": "9"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/5",
#   "waiver_priority": 12
# }}, {'team': {
#   "draft_position": 13,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "ruxandras@rogers.com",
#       "guid": "2JEMDAOSRPYNSM5FPITUBS52RM",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "8",
#       "nickname": "RUXANDRA"
#     }
#   },
#   "name": "RUXANDRA's Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "8",
#   "team_key": "396.l.43832.t.8",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_6.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "6.70"
#   },
#   "team_standings": {
#     "points_for": 6.7,
#     "rank": "10"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/8",
#   "waiver_priority": 7
# }}, {'team': {
#   "draft_position": 18,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "chris.byers13@yahoo.com",
#       "guid": "GFFW3AM4NWPHKBX3WGE2UYAYXY",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "3",
#       "nickname": "Chris"
#     }
#   },
#   "name": "Chris's Team",
#   "number_of_moves": "1",
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "1"
#   },
#   "team_id": "3",
#   "team_key": "396.l.43832.t.3",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1868/57504794742_4b1fec_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "6.50"
#   },
#   "team_standings": {
#     "points_for": 6.5,
#     "rank": "11"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/3",
#   "waiver_priority": 2
# }}, {'team': {
#   "draft_position": 2,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "toczyg@gmail.com",
#       "guid": "RVSZELX23VUTQZSLGDKBWZILFQ",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "10",
#       "nickname": "Greg"
#     }
#   },
#   "name": "The Black Swans",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "10",
#   "team_key": "396.l.43832.t.10",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1586/25024399040_f9b5eb09af_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "6.00"
#   },
#   "team_standings": {
#     "points_for": 6.0,
#     "rank": "12"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/10",
#   "waiver_priority": 18
# }}, {'team': {
#   "draft_position": 6,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "thomas.sf.ng@gmail.com",
#       "guid": "MCKAYK4UJF4OD4PTVABS4RXXEY",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "16",
#       "nickname": "Thomas"
#     }
#   },
#   "name": "Thomas's Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "16",
#   "team_key": "396.l.43832.t.16",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_3_t.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "5.00"
#   },
#   "team_standings": {
#     "points_for": 5.0,
#     "rank": "13"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/16",
#   "waiver_priority": 14
# }}, {'team': {
#   "draft_position": 19,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "tstern@rogers.com",
#       "guid": "NAUPPT4253HJIOJZ2AWRQ3I2KI",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "11",
#       "nickname": "Tracey"
#     }
#   },
#   "name": "TJ Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "11",
#   "team_key": "396.l.43832.t.11",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "3.80"
#   },
#   "team_standings": {
#     "points_for": 3.8,
#     "rank": "14"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/11",
#   "waiver_priority": 1
# }}, {'team': {
#   "draft_position": 17,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "guid": "RBZDFQAX37RGQQKME7GGTAXKFI",
#       "image_url": "https://s.yimg.com/ag/images/4533/38741057351_d2cf5c_64sq.jpg",
#       "manager_id": "4",
#       "nickname": "cosmin"
#     }
#   },
#   "name": "Cosminutz",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "4",
#   "team_key": "396.l.43832.t.4",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1620/25050813150_71933a0149_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "2.50"
#   },
#   "team_standings": {
#     "points_for": 2.5,
#     "rank": "15"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/4",
#   "waiver_priority": 3
# }}, {'team': {
#   "draft_position": 5,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "oren.winer@gmail.com",
#       "guid": "IL3XCIOS3EMGHZ6LKMPFSSO2XE",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "1",
#       "nickname": "Oren"
#     }
#   },
#   "name": "Oren's Team",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "1",
#   "team_key": "396.l.43832.t.1",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1689/24999113210_66a2698cec_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "1.25"
#   },
#   "team_standings": {
#     "points_for": 1.25,
#     "rank": "16"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/1",
#   "waiver_priority": 15
# }}, {'team': {
#   "draft_position": 16,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "a_unterman@yahoo.com",
#       "guid": "GZTTSGIEMIX7CTQNFBQLCTFTDU",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "12",
#       "nickname": "Unty&#39;s Assassins"
#     }
#   },
#   "name": "Unty's Assassins",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "12",
#   "team_key": "396.l.43832.t.12",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_1.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "0.75"
#   },
#   "team_standings": {
#     "points_for": 0.75,
#     "rank": "17"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/12",
#   "waiver_priority": 4
# }}, {'team': {
#   "draft_position": 10,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "ferguson0744@gmail.com",
#       "guid": "FTQ3YNQI4X2RAU5RUVOPAZQEGM",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "2",
#       "nickname": "Aaron"
#     }
#   },
#   "name": "13 Cups",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "2",
#   "team_key": "396.l.43832.t.2",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://s.yimg.com/cv/apiv2/default/nhl/nhl_9_a.png"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "0.00"
#   },
#   "team_standings": {
#     "points_for": 0.0,
#     "rank": "18"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/2",
#   "waiver_priority": 10
# }}, {'team': {
#   "draft_position": 9,
#   "has_draft_grade": 0,
#   "league_scoring_type": "point",
#   "managers": {
#     "manager": {
#       "email": "shafquat1@yahoo.com",
#       "guid": "PDJFZAHN5UBXWO4JJZ5FFBSLN4",
#       "image_url": "https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg",
#       "manager_id": "7",
#       "nickname": "Shafquat"
#     }
#   },
#   "name": "Nylanderthal",
#   "number_of_moves": 0,
#   "number_of_trades": 0,
#   "roster_adds": {
#     "coverage_type": "week",
#     "coverage_value": 1,
#     "value": "0"
#   },
#   "team_id": "7",
#   "team_key": "396.l.43832.t.7",
#   "team_logos": {
#     "team_logo": {
#       "size": "large",
#       "url": "https://ct.yimg.com/cy/1693/24971189389_dfa7c8defd_192sq.jpg?ct=fantasy"
#     }
#   },
#   "team_points": {
#     "coverage_type": "season",
#     "season": "2019",
#     "total": "0.00"
#   },
#   "team_standings": {
#     "points_for": 0.0,
#     "rank": "18"
#   },
#   "url": "https://hockey.fantasysports.yahoo.com/hockey/43832/7",
#   "waiver_priority": 11
# }}]}

# %%
# Convert Standings Object to json
parsed_json = (json.loads(str(standings_data)))

# %%
parsed_json['teams']
# Out:
# [{'team': {'draft_position': 14,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'guid': 'RJ4HIRHI5ZZ47QXMQZB5NWB4AY',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '17',
#      'nickname': 'Jarrod'}},
#    'name': "Jarrod's Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '17',
#    'team_key': '396.l.43832.t.17',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_10_j.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '14.25'},
#    'team_standings': {'points_for': 14.25, 'rank': '1'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/17',
#    'waiver_priority': 6}},
#  {'team': {'draft_position': 3,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'david.r.w.babin@gmail.com',
#      'guid': 'QHYQ4K3QJIQAFIN3PNNLLG6W34',
#      'image_url': 'https://s.yimg.com/ag/images/4734/37610911593_62bc59_64sq.jpg',
#      'manager_id': '14',
#      'nickname': 'David'}},
#    'name': 'The Mighty Pigs',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '14',
#    'team_key': '396.l.43832.t.14',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1814/56476657725_8e0322_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '13.00'},
#    'team_standings': {'points_for': 13.0, 'rank': '2'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/14',
#    'waiver_priority': 17}},
#  {'team': {'draft_position': 4,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'franklin27@rogers.com',
#      'guid': 'RTEILUK2MOBO5QGIMA76QPWDVA',
#      'image_url': 'https://s.yimg.com/ag/images/4543/37864449670_ab6299_64sq.jpg',
#      'manager_id': '6',
#      'nickname': '-- hidden --'}},
#    'name': 'Klin Krush',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '6',
#    'team_key': '396.l.43832.t.6',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_4.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '12.30'},
#    'team_standings': {'points_for': 12.3, 'rank': '3'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/6',
#    'waiver_priority': 16}},
#  {'team': {'draft_position': 1,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'mrhockeypool@yahoo.com',
#      'guid': 'PRCXYO3L6I7LVENMOBV5BZS272',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '9',
#      'nickname': 'Stacey'}},
#    'name': "Stacey's Superb Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '9',
#    'team_key': '396.l.43832.t.9',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '12.00'},
#    'team_standings': {'points_for': 12.0, 'rank': '4'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/9',
#    'waiver_priority': 19}},
#  {'team': {'draft_position': 7,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'spaglia@osc.gov.on.ca',
#      'guid': 'G54BIFJKC3RV2A2UQFQYPCCSGQ',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '18',
#      'nickname': 'Stephen'}},
#    'name': 'Benchwarmers',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '18',
#    'team_key': '396.l.43832.t.18',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_8_b.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '11.25'},
#    'team_standings': {'points_for': 11.25, 'rank': '5'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/18',
#    'waiver_priority': 13}},
#  {'team': {'draft_position': 11,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'miaolong188@yahoo.com',
#      'guid': '54QN76SM6FIBZNCDJE3CJV4OMM',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '13',
#      'nickname': 'Yani'}},
#    'name': "Yani's Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '13',
#    'team_key': '396.l.43832.t.13',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/5046/29952449886_8df2d26330_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '11.20'},
#    'team_standings': {'points_for': 11.2, 'rank': '6'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/13',
#    'waiver_priority': 9}},
#  {'team': {'draft_position': 12,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'michaelbalter@rogers.com',
#      'guid': 'JAAVAZCMHCSOBC326TUKMLRONQ',
#      'image_url': 'https://s.yimg.com/ag/images/4460/37419124544_bb126c_64sq.jpg',
#      'manager_id': '19',
#      'nickname': 'Fig'}},
#    'name': 'Air Duct Cleaners',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '19',
#    'team_key': '396.l.43832.t.19',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_5_m.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '9.20'},
#    'team_standings': {'points_for': 9.2, 'rank': '7'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/19',
#    'waiver_priority': 8}},
#  {'team': {'draft_position': 15,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'jonkatz85@yahoo.ca',
#      'guid': '4LTCKD42U7P7OJ45FZ53W4U2IY',
#      'image_url': 'https://s.yimg.com/ag/images/4573/38099892752_6f450d_64sq.jpg',
#      'manager_id': '15',
#      'nickname': 'Jon'}},
#    'name': "Jon's Team",
#    'number_of_moves': '1',
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '15',
#    'team_key': '396.l.43832.t.15',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_5_j.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '8.25'},
#    'team_standings': {'points_for': 8.25, 'rank': '8'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/15',
#    'waiver_priority': 5}},
#  {'team': {'draft_position': 8,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'smolson12@yahoo.com',
#      'guid': 'MDDMPDULM5IFFUGJ3QAKIEZ5GQ',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '5',
#      'nickname': 'shaun'}},
#    'name': 'Dropping The Gloves',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '5',
#    'team_key': '396.l.43832.t.5',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '7.50'},
#    'team_standings': {'points_for': 7.5, 'rank': '9'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/5',
#    'waiver_priority': 12}},
#  {'team': {'draft_position': 13,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'ruxandras@rogers.com',
#      'guid': '2JEMDAOSRPYNSM5FPITUBS52RM',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '8',
#      'nickname': 'RUXANDRA'}},
#    'name': "RUXANDRA's Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '8',
#    'team_key': '396.l.43832.t.8',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_6.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '6.70'},
#    'team_standings': {'points_for': 6.7, 'rank': '10'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/8',
#    'waiver_priority': 7}},
#  {'team': {'draft_position': 18,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'chris.byers13@yahoo.com',
#      'guid': 'GFFW3AM4NWPHKBX3WGE2UYAYXY',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '3',
#      'nickname': 'Chris'}},
#    'name': "Chris's Team",
#    'number_of_moves': '1',
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '1'},
#    'team_id': '3',
#    'team_key': '396.l.43832.t.3',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1868/57504794742_4b1fec_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '6.50'},
#    'team_standings': {'points_for': 6.5, 'rank': '11'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/3',
#    'waiver_priority': 2}},
#  {'team': {'draft_position': 2,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'toczyg@gmail.com',
#      'guid': 'RVSZELX23VUTQZSLGDKBWZILFQ',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '10',
#      'nickname': 'Greg'}},
#    'name': 'The Black Swans',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '10',
#    'team_key': '396.l.43832.t.10',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1586/25024399040_f9b5eb09af_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '6.00'},
#    'team_standings': {'points_for': 6.0, 'rank': '12'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/10',
#    'waiver_priority': 18}},
#  {'team': {'draft_position': 6,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'thomas.sf.ng@gmail.com',
#      'guid': 'MCKAYK4UJF4OD4PTVABS4RXXEY',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '16',
#      'nickname': 'Thomas'}},
#    'name': "Thomas's Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '16',
#    'team_key': '396.l.43832.t.16',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_3_t.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '5.00'},
#    'team_standings': {'points_for': 5.0, 'rank': '13'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/16',
#    'waiver_priority': 14}},
#  {'team': {'draft_position': 19,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'tstern@rogers.com',
#      'guid': 'NAUPPT4253HJIOJZ2AWRQ3I2KI',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '11',
#      'nickname': 'Tracey'}},
#    'name': 'TJ Team',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '11',
#    'team_key': '396.l.43832.t.11',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_3.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '3.80'},
#    'team_standings': {'points_for': 3.8, 'rank': '14'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/11',
#    'waiver_priority': 1}},
#  {'team': {'draft_position': 17,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'guid': 'RBZDFQAX37RGQQKME7GGTAXKFI',
#      'image_url': 'https://s.yimg.com/ag/images/4533/38741057351_d2cf5c_64sq.jpg',
#      'manager_id': '4',
#      'nickname': 'cosmin'}},
#    'name': 'Cosminutz',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '4',
#    'team_key': '396.l.43832.t.4',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1620/25050813150_71933a0149_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '2.50'},
#    'team_standings': {'points_for': 2.5, 'rank': '15'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/4',
#    'waiver_priority': 3}},
#  {'team': {'draft_position': 5,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'oren.winer@gmail.com',
#      'guid': 'IL3XCIOS3EMGHZ6LKMPFSSO2XE',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '1',
#      'nickname': 'Oren'}},
#    'name': "Oren's Team",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '1',
#    'team_key': '396.l.43832.t.1',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1689/24999113210_66a2698cec_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '1.25'},
#    'team_standings': {'points_for': 1.25, 'rank': '16'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/1',
#    'waiver_priority': 15}},
#  {'team': {'draft_position': 16,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'a_unterman@yahoo.com',
#      'guid': 'GZTTSGIEMIX7CTQNFBQLCTFTDU',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '12',
#      'nickname': 'Unty&#39;s Assassins'}},
#    'name': "Unty's Assassins",
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '12',
#    'team_key': '396.l.43832.t.12',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_1.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '0.75'},
#    'team_standings': {'points_for': 0.75, 'rank': '17'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/12',
#    'waiver_priority': 4}},
#  {'team': {'draft_position': 10,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'ferguson0744@gmail.com',
#      'guid': 'FTQ3YNQI4X2RAU5RUVOPAZQEGM',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '2',
#      'nickname': 'Aaron'}},
#    'name': '13 Cups',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '2',
#    'team_key': '396.l.43832.t.2',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://s.yimg.com/cv/apiv2/default/nhl/nhl_9_a.png'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '0.00'},
#    'team_standings': {'points_for': 0.0, 'rank': '18'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/2',
#    'waiver_priority': 10}},
#  {'team': {'draft_position': 9,
#    'has_draft_grade': 0,
#    'league_scoring_type': 'point',
#    'managers': {'manager': {'email': 'shafquat1@yahoo.com',
#      'guid': 'PDJFZAHN5UBXWO4JJZ5FFBSLN4',
#      'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#      'manager_id': '7',
#      'nickname': 'Shafquat'}},
#    'name': 'Nylanderthal',
#    'number_of_moves': 0,
#    'number_of_trades': 0,
#    'roster_adds': {'coverage_type': 'week', 'coverage_value': 1, 'value': '0'},
#    'team_id': '7',
#    'team_key': '396.l.43832.t.7',
#    'team_logos': {'team_logo': {'size': 'large',
#      'url': 'https://ct.yimg.com/cy/1693/24971189389_dfa7c8defd_192sq.jpg?ct=fantasy'}},
#    'team_points': {'coverage_type': 'season',
#     'season': '2019',
#     'total': '0.00'},
#    'team_standings': {'points_for': 0.0, 'rank': '18'},
#    'url': 'https://hockey.fantasysports.yahoo.com/hockey/43832/7',
#    'waiver_priority': 11}}]

# %%
team_list = []
for team in parsed_json['teams']:
    team_list.append((int(team['team']['team_id']),team['team']['team_standings']['points_for']))
    #print(team['team']['team_id'])
    #print(team['team']['name'])
    #print(team['team']['team_standings']['points_for'])
    #print(team['team']['team_standings']['rank'])

# %%
team_list = sorted(team_list)

# %%
team_list
# Out:
# [(1, 1.25),
#  (2, 0.0),
#  (3, 6.5),
#  (4, 2.5),
#  (5, 7.5),
#  (6, 12.3),
#  (7, 0.0),
#  (8, 6.7),
#  (9, 12.0),
#  (10, 6.0),
#  (11, 3.8),
#  (12, 0.75),
#  (13, 11.2),
#  (14, 13.0),
#  (15, 8.25),
#  (16, 5.0),
#  (17, 14.25),
#  (18, 11.25),
#  (19, 9.2)]

# %%
book = openpyxl.load_workbook('X:/yffpy-batch/fantasy-points/Points.xlsx')
sheet = book.active

# %%
new_excel_row = []
new_excel_row.append(date.today().strftime("%d/%m/%Y"))

for team in team_list:
    new_excel_row.append(team[1])
new_excel_row
# Out:
# ['03/10/2019',
#  1.25,
#  0.0,
#  6.5,
#  2.5,
#  7.5,
#  12.3,
#  0.0,
#  6.7,
#  12.0,
#  6.0,
#  3.8,
#  0.75,
#  11.2,
#  13.0,
#  8.25,
#  5.0,
#  14.25,
#  11.25,
#  9.2]

# %%
sheet.append(new_excel_row)
book.save('Points.xlsx')

# %% [markdown]
# # Try out code for a head-to-head league

# %%
league_id = '138671' # put your real league id here
game_id = "395"
game_code = "nba"
season = "2019"
auth_dir = 'X:/yffpy-batch/'

# %%
yahoo_query = YahooFantasyFootballQuery(auth_dir, league_id, game_id=game_id, game_code=game_code, offline=False)

# %%
# Convert Standings Object to json
parsed_json = (json.loads(str(standings_data)))

team_list = []
for team in parsed_json['teams']:
    #team_list.append((int(team['team']['team_id']),team['team']['team_standings']['team_points']['total']))
    print(team['team']['team_standings'])
#team_list
# Out:
# {'outcome_totals': {'losses': 0, 'percentage': 0.0, 'ties': 0, 'wins': 0}, 'rank': None}
# {'outcome_totals': {'losses': 0, 'percentage': 0.0, 'ties': 0, 'wins': 0}, 'rank': None}
# {'outcome_totals': {'losses': 0, 'percentage': 0.0, 'ties': 0, 'wins': 0}, 'rank': None}

# %%
parsed_json
# Out:
# {'teams': [{'team': {'has_draft_grade': 0,
#     'league_scoring_type': 'head',
#     'managers': {'manager': {'email': 'shafquat1@yahoo.com',
#       'guid': 'PDJFZAHN5UBXWO4JJZ5FFBSLN4',
#       'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#       'manager_id': '1',
#       'nickname': 'Shafquat'}},
#     'name': "Shafquat's Team",
#     'number_of_moves': 0,
#     'number_of_trades': 0,
#     'roster_adds': {'coverage_type': 'week',
#      'coverage_value': '1',
#      'value': '0'},
#     'team_id': '1',
#     'team_key': '395.l.138671.t.1',
#     'team_logos': {'team_logo': {'size': 'large',
#       'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4_s.png'}},
#     'team_points': {'coverage_type': 'season',
#      'season': '2019',
#      'total': None},
#     'team_standings': {'outcome_totals': {'losses': 0,
#       'percentage': 0.0,
#       'ties': 0,
#       'wins': 0},
#      'rank': None},
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/138671/1',
#     'waiver_priority': None}},
#   {'team': {'has_draft_grade': 0,
#     'league_scoring_type': 'head',
#     'managers': {'manager': {'email': 'dimitri.bollegala@gmail.com',
#       'guid': 'TAX2FSV2C63SF3KDVRXBFOI42E',
#       'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#       'manager_id': '2',
#       'nickname': 'Dimitri'}},
#     'name': "Dimitri's Team",
#     'number_of_moves': 0,
#     'number_of_trades': 0,
#     'roster_adds': {'coverage_type': 'week',
#      'coverage_value': '1',
#      'value': '0'},
#     'team_id': '2',
#     'team_key': '395.l.138671.t.2',
#     'team_logos': {'team_logo': {'size': 'large',
#       'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_2_d.png'}},
#     'team_points': {'coverage_type': 'season',
#      'season': '2019',
#      'total': None},
#     'team_standings': {'outcome_totals': {'losses': 0,
#       'percentage': 0.0,
#       'ties': 0,
#       'wins': 0},
#      'rank': None},
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/138671/2',
#     'waiver_priority': None}},
#   {'team': {'has_draft_grade': 0,
#     'league_scoring_type': 'head',
#     'managers': {'manager': {'email': 'rsandulescu@yahoo.ca',
#       'guid': '2JEMDAOSRPYNSM5FPITUBS52RM',
#       'image_url': 'https://ct.yimg.com/cy/1768/39361574426_98028a_64sq.jpg',
#       'manager_id': '3',
#       'nickname': 'RUXANDRA'}},
#     'name': "RUXANDRA's Team",
#     'number_of_moves': 0,
#     'number_of_trades': 0,
#     'roster_adds': {'coverage_type': 'week',
#      'coverage_value': '1',
#      'value': '0'},
#     'team_id': '3',
#     'team_key': '395.l.138671.t.3',
#     'team_logos': {'team_logo': {'size': 'large',
#       'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_11_r.png'}},
#     'team_points': {'coverage_type': 'season',
#      'season': '2019',
#      'total': None},
#     'team_standings': {'outcome_totals': {'losses': 0,
#       'percentage': 0.0,
#       'ties': 0,
#       'wins': 0},
#      'rank': None},
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/138671/3',
#     'waiver_priority': None}}]}
